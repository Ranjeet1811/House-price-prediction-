# %% [markdown]
# # import important libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Load dataset

# %%
housing=pd.read_csv('housing.csv')

# %%
housing.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458    NaN  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
housing.shape
# Out:
# (506, 14)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       501 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
# checking null values in dataset

# %%
housing.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         5
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
# checking coelation

# %%
housing.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.220058  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.313475 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.392334  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091255  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.301914  0.731470
# rm      -0.220058  0.313475 -0.392334  0.091255 -0.301914  1.000000 -0.240780
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240780  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.206393 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.210684  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292826  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.359968  0.261515
# ...

# %%
housing.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.285170
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.704749
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.209000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
housing.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458    NaN  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# checking colum 'chas' unique values

# %%
housing['chas'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
import seaborn as sns

# %%
sns.pairplot(housing)

# %%
housing['chas'].value_counts()
# Out:
# 0    471
# 1     35
# Name: chas, dtype: int64

# %%
# checking unique values in dataset 
housing.nunique().sort_values()
# Out:
# chas         2
# rad          9
# zn          26
# ptratio     46
# tax         66
# indus       76
# nox         81
# medv       229
# age        356
# b          357
# dis        412
# rm         442
# lstat      455
# crim       504
# dtype: int64

# %%
housing['rad'].value_counts()
# Out:
# 24    132
# 5     115
# 4     110
# 3      38
# 6      26
# 2      24
# 8      24
# 1      20
# 7      17
# Name: rad, dtype: int64

# %%
housing.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.285170
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.704749
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.209000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
housing.hist(bins=30,figsize=(20,15))
plt.show()

# %%
# let's split the dataset training and testing 
from sklearn.model_selection import train_test_split
train_set,test_set=train_test_split(housing,test_size=0.2,random_state=42)

# %%
train_set.shape
# Out:
# (404, 14)

# %%
test_set.shape
# Out:
# (102, 14)

# %%
print(f"Row in train_set:{len(train_set)}\n Row in test_set:{len(test_set)}\n" )
# Out:
# Row in train_set:404
#  Row in test_set:102

# %%
# using StratifiedShuffledsplit model split the dataset colums value  equally train and testing  so that we can predict good prediction 
from sklearn.model_selection import StratifiedShuffleSplit
split=StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)
for train_index,test_index in split.split(housing,housing['chas']):
    strat_train_set=housing.loc[train_index]
    strat_test_set=housing.loc[test_index]

# %%
strat_test_set['chas'].value_counts()
# Out:
# 0    95
# 1     7
# Name: chas, dtype: int64

# %%
strat_train_set['chas'].value_counts()
# Out:
# 0    376
# 1     28
# Name: chas, dtype: int64

# %%
95/7
# Out:
# 13.571428571428571

# %%
376/28
# Out:
# 13.428571428571429

# %%
#looking for correlations

# %%
corr_matrix=housing.corr()
corr_matrix['medv'].sort_values(ascending=False)
# Out:
# medv       1.000000
# rm         0.694724
# zn         0.360445
# b          0.333461
# dis        0.249929
# chas       0.175260
# age       -0.376955
# rad       -0.381626
# crim      -0.388305
# nox       -0.427321
# tax       -0.468536
# indus     -0.483725
# ptratio   -0.507787
# lstat     -0.737663
# Name: medv, dtype: float64

# %%
from pandas.plotting import scatter_matrix
att=['medv','rm','zn','lstat']
scatter_matrix(housing[att],figsize=(12,8))
plt.show()

# %%
# plot between feature 'rm' and 'medv'
housing.plot(kind='scatter',x='rm',y='medv',alpha=0.8)
plt.show()

# %%
housing['txrm']=housing['tax']/housing['rm']

# %%
housing.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458    NaN  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv       txrm
# 0  396.90   4.98  24.0  45.019011
# 1  396.90   9.14  21.6  37.688834
# 2  392.83   4.03  34.7  33.681280
# 3  394.63   2.94  33.4        NaN
# 4  396.90   5.33  36.2  31.061984

# %%
corr_matrix=housing.corr()
corr_matrix['medv'].sort_values(ascending=False)
# Out:
# medv       1.000000
# rm         0.694724
# zn         0.360445
# b          0.333461
# dis        0.249929
# chas       0.175260
# age       -0.376955
# rad       -0.381626
# crim      -0.388305
# nox       -0.427321
# tax       -0.468536
# indus     -0.483725
# ptratio   -0.507787
# txrm      -0.537050
# lstat     -0.737663
# Name: medv, dtype: float64

# %%
housing.plot(kind='scatter',x='txrm',y='medv',alpha=0.8)
plt.show()

# %%
housing.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         5
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# txrm       5
# dtype: int64

# %%
# convert data in x and y form 
housing=strat_train_set.drop('medv',axis=1)
housing_labels=strat_train_set['medv'].copy()

# %% [markdown]
# # Missing attributes

# %% [markdown]
# 1.get rid of missing data points
# 2. get rid of the whole attribute
#  3. set the value to some value (0,mean or median)

# %%
a=housing.dropna(subset=['rm']) #op-tion 1

# %%
a.shape
# Out:
# (399, 13)

# %%
housing.drop('rm',axis=1).shape # option 2
# there is no rm columns and aslo note that the original housing dataframe will unchanged
# Out:
# (404, 12)

# %%
median=housing['rm'].median() # option 3  computer median

# %%
median=housing['rm'].median()frame will unchanged
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.376
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     7.820
# 455    6.525
# 216    5.888
# Name: rm, Length: 404, dtype: float64

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='median')
imputer.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([2.86735e-01, 0.00000e+00, 9.90000e+00, 0.00000e+00, 5.38000e-01,
#        6.21100e+00, 7.82000e+01, 3.12220e+00, 5.00000e+00, 3.37000e+02,
#        1.90000e+01, 3.90955e+02, 1.15700e+01])

# %%
imputer.statistics_
# Out:
# array([2.86735e-01, 0.00000e+00, 9.90000e+00, 0.00000e+00, 5.38000e-01,
#        6.21100e+00, 7.82000e+01, 3.12220e+00, 5.00000e+00, 3.37000e+02,
#        1.90000e+01, 3.90955e+02, 1.15700e+01])

# %%
x=imputer.transform(housing)

# %%
housing_tr=pd.DataFrame(x,columns=housing.columns)

# %%
housing_tr.describe()
# rm total count is 506 replaced missing value using median
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.279661
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.711342
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.879750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.211000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630000
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %% [markdown]
# # Scikit-learn Design

# %% [markdown]
# Primarily three types of objects
# 1. Estimators - IT estimates some parameters based on a dataset Eg. imputer
# it has a fit method and tranform method
# fit method- Fits the datasets and calulates internal parameters
# 2. Transformers-  fit and transform ()
# 3. Predictor-  fit(),predict(),also give score()

# %% [markdown]
# # Feature scalling

# %% [markdown]
#     two type
# 1. min-max scaling (Normalization)
#    (value-min)/(max-min)
#    sklearn  provides a class called MinMaxScaler for this
# 2. Standardization - (value-mean)/std
#    sklearn provides a class called Standard Scaler for this

# %% [markdown]
# ## Creating a pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline=Pipeline([
    ('imputer',SimpleImputer(strategy='median')),
    ('std_scaler',StandardScaler()),
])

# %%
housing_num_tr=my_pipeline.fit_transform(housing_tr)

# %%
housing_num_tr.shape
# Out:
# (404, 13)

# %% [markdown]
# # Selecting a desired model for housing price predictor

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()
#model=DecisionTreeRegressor()
#model=LinearRegression()
model.fit(housing_num_tr,housing_labels)
# Out:
# RandomForestRegressor()

# %%
some_data=housing.iloc[:5]

# %%
some_labels=housing_labels.iloc[:5]

# %%
prepared_data =my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([22.444, 25.797, 16.769, 23.286, 23.638])

# %%
list(some_labels)
# Out:
# [21.9, 24.5, 16.7, 23.1, 23.0]

# %% [markdown]
# # Evaluating the model

# %%
from sklearn.metrics import mean_squared_error
housing_prediction=model.predict(housing_num_tr)
mse=mean_squared_error(housing_labels,housing_prediction)
rmse=np.sqrt(mse)

# %%
rmse
# Out:
# 1.2395173615581019

# %%
## using better Evaluation technique-cross Validatio 
from sklearn.model_selection import cross_val_score
scores=cross_val_score(model,housing_num_tr,housing_labels,scoring="neg_mean_squared_error", cv=10)
rmse_score=np.sqrt(-scores)

# %%
rmse_score
# Out:
# array([2.80631878, 2.79572266, 4.5523226 , 2.67692267, 3.34470681,
#        2.5805005 , 4.53200016, 3.34556143, 3.03165286, 3.48154839])

# %%
def print_score(scores):
    print("Scores",scores)
    print("Mean",scores.mean())
    print("Standard deviation: ", scores.std())

# %%
print_score(rmse_score)
# Out:
# Scores [2.80631878 2.79572266 4.5523226  2.67692267 3.34470681 2.5805005
#  4.53200016 3.34556143 3.03165286 3.48154839]
# Mean 3.3147256871424444
# Standard deviation:  0.6780069362804416
